# %% [markdown]
# # stabilityai/stable-diffusion-2

# %% [markdown]
# ## Install Package

# %%
pip install diffusers -i https://mirrors.aliyun.com/pypi/simple/
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 770.1 kB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install accelerate scipy safetensors -i https://mirrors.aliyun.com/pypi/simple/
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 380.5 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.5/36.5 MB 1.3 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Download Models

# %%
from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler
import os
import torch
os.environ['CURL_CA_BUNDLE'] = ''
os.environ["HTTP_PROXY"] = "http://proxy.vmware.com:3128"
os.environ["HTTPS_PROXY"] = "http://proxy.vmware.com:3128"

model_id = "stabilityai/stable-diffusion-2"

# Use the Euler scheduler here instead
scheduler = EulerDiscreteScheduler.from_pretrained(model_id, subfolder="scheduler")
pipe = StableDiffusionPipeline.from_pretrained(model_id, scheduler=scheduler, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "a photo of an astronaut riding a horse on mars"
image = pipe(prompt).images[0]
    
image.save("astronaut_rides_horse.png")
# Out:
# ...
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# ...
#
# ...
#
# ...
#
# ...
# Fetching 12 files:   8%|▊         | 1/12 [00:01<00:20,  1.89s/it]
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
# Fetching 12 files:  25%|██▌       | 3/12 [00:03<00:10,  1.16s/it]
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...

# %%
prompt = "a photo of a cute cat"
image1 = pipe(prompt).images[0]
    
image1.save("cute_cat.png")
image1
# Out:
# 100%|██████████| 50/50 [00:27<00:00,  1.84it/s]
# <PIL.Image.Image image mode=RGB size=768x768>

# %%
prompt = "a photo of an astronaut riding a horse on mars"
image = pipe(prompt).images[0]
    
image.save("astronaut_rides_horse.png")
image
# Out:
# 100%|██████████| 50/50 [00:27<00:00,  1.83it/s]
# <PIL.Image.Image image mode=RGB size=768x768>
